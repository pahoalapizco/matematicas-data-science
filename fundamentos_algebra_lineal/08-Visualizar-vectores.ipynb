# %% [markdown]
# # Visualizar vectores

# %% [markdown]
# La visualización de vectores en un grafico, no sire como herramienta a la hora de estudiar las combinaciones lineales de ecuaciones.
#
# Esta herramienta tiene otras ventajas, tales como:
# - Facilita la comprensión de operaciones vectoriales
# - Permite visualizar las transformaciones lineales
# - Comprender la dependencia e independencial linal
# - Visualización de espacios vectoriales y subespacios
#
# La lista continua...

# %% [markdown]
# ## Ejemplo:

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# Definimos los vectores
v1 = np.array([3,5])
v2 = np.array([3,2])

# %%
# %run "./auxiliares/graficar-vectores.ipynb"

# %%
plot_vectors([v1, v2], ["blue", "orange"])

# %% [markdown]
# Suma de ambos vectores:

# %%
v3 = v1 + v2
plot_vectors([v1, v2, v3], ["blue", "orange", "red"])
