# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Funciones compuestas
# Son aquellas que se crean combinando do o más funciones.

# %% [markdown]
# Se utiliza la salida(rango) de una función como entrada(dominio) para otra función. <br>
# En terminos matemáticos se expresa como:
#
# $$ f \space o \space g = (f \space o \space g)(x) = f(g(x))$$

# %%
N = 1000

# funciones:
def g(x):
    return x**2

def f(x):
    return np.cos(x)

x = np.linspace(-10, 10, num=N)
f_o_g = f(g(x)) # El resultado de la función g para como argumento a la función f

plt.plot(x,f_o_g)
plt.grid()

# %% [markdown]
# Otra forma de implementar las funciones compuestas:

# %%
# Para este caso invertí el orden de las funciones
y = f(x)
g_o_f = g(y) # la variable y tiene el resultado de la función f, dicho resultado se pasa como argumento a la función g

plt.plot(x,f_o_g)
plt.grid()
