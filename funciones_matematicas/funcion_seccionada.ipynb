# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Función seccionada

# %% [markdown]
# Son funciones que tienen diferentes valores definidos por un intervalo. <br>
# Un ejemplo es la función "_escalón de Heaviside_"
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %%
def H(x):
    Y = np.zeros(len(x))
    for idx, x in enumerate(x):
        if x >= 0:
            Y[idx] = 1
    return Y

# %%
N = 1000
x = np.linspace(-10, 10, num=N)

y = H(x)

plt.plot(x, y)
plt.grid()

# %% [markdown]
# Otra forma de representar con python la función de Heaviside:

# %%
def H(x):
    return np.where(x >= 0, 1, 0)

# %%
y = H(x)

plt.plot(x, y)
plt.grid()

# %% [markdown]
# ## Función de valor absoluto

# %% [markdown]
# La función de valor absoluto es una función matemática que se utiliza para calcular la distancia entre un número y cero en una línea numérica. La función toma cualquier número real como entrada y devuelve su valor absoluto, que siempre es un número positivo.
#
# Se define como:
# > Para cualquier número real $x$, el valor absoluto de $x$ se denota por $|x|$:
#
#
# $|x| = x$, si es mayor o igual que 0, $x >= 0$
# <br>
# $|x| = x$, si es menor que 0, $x < 0$

# %%
def abosulo(x):
    Y = x.copy()
    for idx, x in enumerate(x):
        if x < 0:
            Y[idx] = x*(-1)
    return Y

y = abosulo(x)

plt.plot(x,y)
plt.grid()
